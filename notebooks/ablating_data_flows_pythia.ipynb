# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../")
import copy

import logging
from src.utils import logging_utils
from src import functional
from src.models import ModelandTokenizer
# from src.data import load_relation

logger = logging.getLogger(__name__)

logging.basicConfig(
    level=logging.DEBUG,
    format=logging_utils.DEFAULT_FORMAT,
    datefmt=logging_utils.DEFAULT_DATEFMT,
    stream=sys.stdout,
)

# %%
import torch
import transformers
import baukit
from transformers import AutoModelForCausalLM, AutoTokenizer
from src.models import ModelandTokenizer

# state-spaces/mamba-2.8b | state-spaces/mamba-2.8b-slimpj
MODEL_PATH = "EleutherAI/pythia-2.8b-deduped"  

mt = ModelandTokenizer(
    model_path=MODEL_PATH, 
    torch_dtype=torch.float32
)
# Out:
# 2024-04-01 16:45:21 urllib3.connectionpool DEBUG    Starting new HTTPS connection (1): huggingface.co:443
# 2024-04-01 16:45:21 urllib3.connectionpool DEBUG    https://huggingface.co:443 "HEAD /EleutherAI/pythia-2.8b-deduped/resolve/main/config.json HTTP/1.1" 200 0
# 2024-04-01 16:45:22 urllib3.connectionpool DEBUG    https://huggingface.co:443 "HEAD /EleutherAI/pythia-2.8b-deduped/resolve/main/generation_config.json HTTP/1.1" 404 0
# 2024-04-01 16:45:24 urllib3.connectionpool DEBUG    https://huggingface.co:443 "HEAD /EleutherAI/pythia-2.8b-deduped/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-04-01 16:45:24 src.models INFO     loaded model <EleutherAI/pythia-2.8b-deduped> | size: 10724.583 MB | dtype: torch.float32 | device: cuda

# %%
prompt_template = mt.tokenizer.eos_token + " {} is located in the city of"
subject = "Louvre"
alt_subject = "The Space Needle"

functional.predict_next_token(
    mt = mt,
    prompt = [
        prompt_template.format(subject),
        prompt_template.format(alt_subject),
    ]
)
# Out:
# [[PredictedToken(token=' Paris', prob=0.41835397481918335),
#   PredictedToken(token=' the', prob=0.06783477216959),
#   PredictedToken(token=' Vers', prob=0.03427596390247345),
#   PredictedToken(token=' Lou', prob=0.031185207888484),
#   PredictedToken(token=' L', prob=0.0243191197514534)],
#  [PredictedToken(token=' Seattle', prob=0.9864033460617065),
#   PredictedToken(token=' Ed', prob=0.001737017068080604),
#   PredictedToken(token='Se', prob=0.0017044860869646072),
#   PredictedToken(token=' Iss', prob=0.0014102683635428548),
#   PredictedToken(token=' Belle', prob=0.00098050432279706)]]

# %%
import copy
import json
import logging
import types
from collections import defaultdict
from typing import Literal, Optional, get_args

import baukit
import numpy
import torch
from tqdm import tqdm

import src.tokens as tokenizer_utils

# from mamba_ssm.models.mixer_seq_simple import MambaLMHeadModel as Mamba
from mamba_minimal.model import Mamba
from src import functional
from src.functional import (
    decode_tokens,
    find_token_range,
    make_inputs,
    predict_from_input,
)
from src.hooking.mamba import MambaBlock_Hook_Points, MambaBlockForwardPatcher
from src.models import ModelandTokenizer, is_mamba_variant

# %%
from src.utils.typing import Mamba
type(mt.model), Mamba
# Out:
# (transformers.models.gpt_neox.modeling_gpt_neox.GPTNeoXForCausalLM,
#  mamba_minimal.model.Mamba)

# %%
isinstance(mt.model, Mamba)
# Out:
# False

# %%
def path_ablation(
    mt,
    inp,  # A set of inputs
    residual_states_to_patch,  # A list of (token index, layername) triples to restore
    answers_t,  # Answer probabilities to collect
    tokens_to_mix,  # Range of tokens to corrupt (begin, end)
    noise=0.1,  # Level of noise to add
    uniform_noise=False,
    replace=False,  # True to replace with instead of add noise
    alt_subj_patching: bool = False,  # If True, will assume inp shape to be (2, L). Uncorrupted activations with inp[0] will be patched in the run with inp[1]. Will not corrupt the embeddings
    block_states_to_unpatch: (list) = [],  # A list of (token index, layername) triples to restore in the uncorrupted run
    hook_to_unpatch: Optional[
        MambaBlock_Hook_Points
    ] = None,
):
    assert alt_subj_patching == True, "only alt_subj_patching is supported for now"
    # assert is_mamba_variant(mt), "This function is only for Mamba models. check trace_with_repatch in the original implementation for other models"
    embed_layername = mt.embedder_name

    rs = numpy.random.RandomState(1)  # For reproducibility, use pseudorandom noise
    if uniform_noise:
        prng = lambda *shape: rs.uniform(-1, 1, shape)
    else:
        prng = lambda *shape: rs.randn(*shape)

    residual_patch_spec = defaultdict(list)
    for t, l in residual_states_to_patch:
        residual_patch_spec[l].append(t)
    
    block_unpatch_spec = defaultdict(list)
    for t, l in block_states_to_unpatch:
        block_unpatch_spec[l].append(t)
    
    # print(f"{residual_patch_spec=}")
    # print(f"{block_unpatch_spec=}")

    def untuple(x):
        return x[0] if isinstance(x, tuple) else x

    # Define the model-patching rule.
    if isinstance(noise, float):
        noise_fn = lambda x: noise * x
    else:
        noise_fn = noise

    def patch_rep(repr, layer):
        assert first_run_residual_activations is not None

        if layer == embed_layername and alt_subj_patching == False:
            # If requested, we corrupt a range of token embeddings on batch items x[1:]
            if tokens_to_mix is not None:
                b, e = tokens_to_mix
                noise_data = noise_fn(
                    torch.from_numpy(prng(repr.shape[0] - 1, e - b, repr.shape[2]))
                ).to(repr.device)
                if replace:
                    repr[1:, b:e] = noise_data
                else:
                    repr[1:, b:e] += noise_data
            return repr
        
        if layer not in residual_patch_spec and layer not in block_unpatch_spec:
            # no intervention needed. just continue
            return repr
        
        # If this layer is in the patch_spec, restore the uncorrupted hidden state
        # for selected tokens from the first run
        h = untuple(repr)
        if layer in residual_patch_spec:
            for t in residual_patch_spec[layer]:
                h[1:, t] = untuple(first_run_residual_activations[layer].output)[0, t]
        
        
        if layer in block_unpatch_spec:
            for t in block_unpatch_spec[layer]:
                # print(f">>>>> corrupting {layer} at token {t}")
                h[1:, t] = untuple(first_run_residual_activations[layer].output)[1, t]

        return repr

    mt.reset_forward()  # reset the model to use default forward functions

    # need to run twice to store corrupted and uncorrupted activations
    # of hooks inside the MambaBlock (Is there a better way?)
    interested_layers = list(set(
        list(residual_patch_spec.keys()) + list(block_unpatch_spec.keys())
    ))

    # print(f"{interested_layers=}")

    if is_mamba_variant(mt):
        first_run_hook_activations = {layer: {} for layer in interested_layers}
        # print(f"{first_run_hook_activations.keys()=}")
        for layer in interested_layers:
            block = baukit.get_module(
                mt.model, name=layer + ".mixer"
            )  # MambaBlock naming format
            block.forward = types.MethodType(
                MambaBlockForwardPatcher(
                    retainer=first_run_hook_activations[layer],
                ),  # get everything for the uncorrupted run
                block,
            )

    states_to_cache = [embed_layername] + list(residual_patch_spec.keys())
    if is_mamba_variant(mt) == False:
        states_to_cache += list(block_unpatch_spec.keys())
    with torch.inference_mode(), baukit.TraceDict(
        mt.model,
        states_to_cache,
        edit_output = None # No intervention on the clean run
    ) as td:
        mt(**inp)

    first_run_residual_activations = td

    # print(f"{first_run_residual_activations.keys()=}")

    # ------------------------------------------------------
    # second run with patching / unpatching

    if is_mamba_variant(mt):
        mt.reset_forward()  # reset the model to use default forward functions
        for layer in block_unpatch_spec:
            block = baukit.get_module(mt.model, name=layer + ".mixer")

            # restore the corrupted activations inside the MambaBlock here
            # the patching with clean residual states will be done in patch_rep
            cur_patch_spec = {
                token_idx: first_run_hook_activations[layer][hook_to_unpatch][1, t] # corrupted activations
                for token_idx in block_unpatch_spec[layer]
            }  
            block.forward = types.MethodType(
                MambaBlockForwardPatcher(
                    patch_spec=cur_patch_spec,
                    patch_hook=hook_to_unpatch,
                ),
                block,
            )

    with torch.inference_mode(), baukit.TraceDict(
        mt.model,
        states_to_cache,
        edit_output=patch_rep, 
    ):
        outputs_exp = mt.model(input_ids=inp["input_ids"])
    # ------------------------------------------------------
    mt.reset_forward()  # reset the model to use default forward functions

    # We report softmax probabilities for the answers_t token predictions of interest.
    logits = outputs_exp.logits if hasattr(outputs_exp, "logits") else outputs_exp
    probs = torch.softmax(logits[1:, -1, :], dim=1).mean(dim=0)[answers_t]

    return probs

# %%
def trace_important_states_with_ablation(
    mt,
    inp,
    e_range,
    answer_t,
    noise=0.1,
    uniform_noise=False,
    replace=False,
    token_range=None,
    ablate_mambahook: Optional[MambaBlock_Hook_Points] = None,
    ablate_transformer_module: Optional[Literal["mlp", "attn"]] = None,
    alt_subj_patching: bool = False,
):
    assert ablate_mambahook is None or ablate_transformer_module is None
    ntoks = inp["input_ids"].shape[1]
    table = []
    if token_range is None:
        token_range = range(ntoks)

    for tnum in token_range:
        block_states_to_unpatch = []
        if ablate_mambahook is not None:
            block_states_to_unpatch = [
                (tnum, mt.layer_name_format.format(layer)) for layer in range(0, mt.n_layer)
            ]
        if ablate_transformer_module is not None:
            # print("?????", ablate_transformer_module)
            if ablate_transformer_module == "mlp":
                module_name_format = mt.mlp_module_name_format
            elif ablate_transformer_module == "attn":
                module_name_format = mt.attn_module_name_format
            else:
                raise ValueError(f"Invalid transformer module name => {ablate_transformer_module}")
            
            block_states_to_unpatch = [
                (tnum, module_name_format.format(layer)) for layer in range(0, mt.n_layer)
            ]
        # print(block_states_to_unpatch)

        row = []
        for layer in range(mt.n_layer):
            r = path_ablation(
                mt = mt,
                inp = inp,
                residual_states_to_patch=[(tnum, mt.layer_name_format.format(layer))],
                answers_t=answer_t,
                tokens_to_mix=e_range,
                noise=noise,
                uniform_noise=uniform_noise,
                replace=replace,
                block_states_to_unpatch=block_states_to_unpatch,
                hook_to_unpatch=ablate_mambahook,
                alt_subj_patching=alt_subj_patching,
            )
            row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)

# %%
from src.tracing import trace_with_patch, replace_eos_with_pad

def calculate_hidden_flow_with_ablation(
    mt: ModelandTokenizer,
    prompt: str,
    subject: str,
    alt_subject: Optional[str] = None,
    num_samples=10,
    noise=0.1,
    token_range=None,
    uniform_noise=False,
    replace=False,
    window=10,
    ablate_mambahook: Optional[MambaBlock_Hook_Points] = None,
    ablate_transformer_module: Optional[Literal["mlp", "attn"]] = None,
):
    # print(" >>>>", ablate_transformer_module)
    assert ablate_mambahook is None or ablate_transformer_module is None, "Only one of ablate_mambahook or ablate_transformer_module can be set"
    if alt_subject is None:
        inp = make_inputs(mt.tokenizer, [prompt] * (num_samples + 1))
        with torch.no_grad():
            answer_t, base_score = [d[0] for d in predict_from_input(mt.model, inp)]
        e_range = find_token_range(
            string=prompt,
            substring=subject,
            tokenizer=mt.tokenizer,
        )
        low_score = trace_with_patch(
            mt,
            inp,
            [],
            answer_t,
            e_range,
            noise=noise,
            uniform_noise=uniform_noise,
            mamba_block_hook=None,  # don't need to patch for calculating the low score
            alt_subj_patching=alt_subject is not None,
        ).item()
    else:
        if "{}" in prompt:
            prompt = prompt.format(subject)
        clean_prompt = prompt
        alt_prompt = prompt.replace(subject, alt_subject)
        with tokenizer_utils.set_padding_side(mt.tokenizer, padding_side="left"):
            inp = mt.tokenizer(
                [clean_prompt, alt_prompt],
                return_tensors="pt",
                padding="longest",
                return_offsets_mapping=True,
            ).to(mt.device)
        offset_mapping = inp.pop("offset_mapping")
        subject_range = find_token_range(
            string=clean_prompt,
            substring=subject,
            tokenizer=mt.tokenizer,
            offset_mapping=offset_mapping[0],
        )
        alt_subj_range = find_token_range(
            string=alt_prompt,
            substring=alt_subject,
            tokenizer=mt.tokenizer,
            offset_mapping=offset_mapping[1],
        )
        assert subject_range[1] == alt_subj_range[1]
        e_range = (min(subject_range[0], alt_subj_range[0]), subject_range[1])

        with torch.no_grad():
            outputs = mt(**inp)
        logits = outputs.logits[:, -1] if hasattr(outputs, "logits") else outputs[:, -1]
        next_token_probs = logits.float().softmax(dim=-1)
        answer_t = next_token_probs[0].argmax(dim=-1)
        base_score = next_token_probs[0, answer_t]  # p(ans|subj)
        low_score = next_token_probs[1, answer_t]  # p(ans|alt_subj)
    
    
    if token_range == "subject_last":
        token_range = [e_range[1] - 1]
    elif token_range == "prompt_last":
        token_range = [inp["input_ids"].shape[1] - 1]
    elif token_range is not None:
        raise ValueError(f"Unknown token_range: {token_range}")

    
    [answer] = decode_tokens(mt.tokenizer, [answer_t])

    differences = trace_important_states_with_ablation(
        mt =  mt,
        inp =  inp,
        e_range = e_range,
        answer_t = answer_t,
        noise = noise,
        uniform_noise = uniform_noise,
        replace = replace,
        token_range = token_range,
        ablate_mambahook = ablate_mambahook,
        ablate_transformer_module = ablate_transformer_module,
        alt_subj_patching=alt_subject is not None,
    )

    differences = differences.detach().cpu()
    indirect_effect = dict(
        scores=differences,
        low_score=low_score,
        high_score=base_score,
        input_ids=inp["input_ids"][0],
        input_tokens=replace_eos_with_pad(
            mt.tokenizer, list(decode_tokens(mt.tokenizer, inp["input_ids"][0]))
        ),
        subject_range=e_range,
        answer=answer,
        window=window,
        correct_prediction=True,
        kind=ablate_mambahook or ablate_transformer_module,
    )

    if alt_subject is not None:
        indirect_effect["alt_subject"] = replace_eos_with_pad(
            mt.tokenizer,
            list(
                decode_tokens(
                    mt.tokenizer, inp["input_ids"][1, e_range[0] : e_range[1]]
                )
            ),
        )

    return indirect_effect

# %%
# from src.plotting import plot_trace_heatmap

# indirect_effect = calculate_hidden_flow_with_ablation(
#     mt = mt,
#     prompt = prompt_template,
#     subject = subject,
#     alt_subject = alt_subject,
#     num_samples = 10,
#     noise = 0.1,
#     token_range = None,
#     uniform_noise = False,
#     replace = False,
#     window = 10,
#     ablate_mambahook = None,
# )

# plot_trace_heatmap(indirect_effect, modelname=MODEL_PATH.split("/")[-1])

# %%
# indirect_effect_ablate_ssm = calculate_hidden_flow_with_ablation(
#     mt = mt,
#     prompt = prompt_template,
#     subject = subject,
#     alt_subject = alt_subject,
#     num_samples = 10,
#     noise = 0.1,
#     token_range = None,
#     uniform_noise = False,
#     replace = False,
#     window = 10,
#     # ablate_mambahook = "ssm_after_ssm",
#     ablate_transformer_module="mlp",
# )
# plot_trace_heatmap(indirect_effect_ablate_ssm, modelname=MODEL_PATH.split("/")[-1])

# %%
# indirect_effect_ablate_other = calculate_hidden_flow_with_ablation(
#     mt = mt,
#     prompt = prompt_template,
#     subject = subject,
#     alt_subject = alt_subject,
#     num_samples = 10,
#     noise = 0.1,
#     token_range = None,
#     uniform_noise = False,
#     replace = False,
#     window = 10,
#     # ablate_mambahook = "mlp_after_silu",
#     ablate_transformer_module="attn",
# )
# plot_trace_heatmap(indirect_effect_ablate_other, modelname=MODEL_PATH.split("/")[-1])

# %%
kwargs = dict(
    mt = mt,
    prompt = prompt_template,
    subject = subject,
    alt_subject = alt_subject,
    num_samples = 10,
    noise = 0.1,
    token_range = "subject_last",
    uniform_noise = False,
    replace = False,
    window = 10,
)

indirect_effect = calculate_hidden_flow_with_ablation(
    **kwargs,
)

indirect_effect_attn_severed = calculate_hidden_flow_with_ablation(
    ablate_transformer_module="attn",
    **kwargs,
)

indirect_effect_mlp_severed = calculate_hidden_flow_with_ablation(
    ablate_transformer_module="mlp",
    **kwargs,
)

high_score = indirect_effect["high_score"].item()
low_score = indirect_effect["low_score"].item()

ie = (indirect_effect["scores"] - low_score) / (high_score - low_score)
ie_attn_severed = (indirect_effect_attn_severed["scores"] - low_score) / (high_score - low_score)
ie_mlp_severed = (indirect_effect_mlp_severed["scores"] - low_score) / (high_score - low_score)
# ie_block_severed = (indirect_effect_block_severed["scores"] - low_score) / (high_score - low_score)

# %%
indirect_effect_mlp_severed = calculate_hidden_flow_with_ablation(
    ablate_transformer_module="mlp",
    **kwargs,
)

# %%
import matplotlib.pyplot as plt
import numpy as np

#####################################################################################
plt.rcParams["figure.dpi"] = 200
plt.rcParams["font.family"] = "Times New Roman"

SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 24

plt.rc("font", size=SMALL_SIZE)  # controls default text sizes
plt.rc("axes", titlesize=BIGGER_SIZE)  # fontsize of the axes title
plt.rc("axes", labelsize=MEDIUM_SIZE+5)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SMALL_SIZE)  # fontsize of the tick labels
plt.rc("ytick", labelsize=MEDIUM_SIZE)  # fontsize of the tick labels
plt.rc("legend", fontsize=SMALL_SIZE)  # legend fontsize
plt.rc("axes", titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc("figure", titlesize=BIGGER_SIZE)  # fontsize of the figure title
#####################################################################################

def plot_aie_subject_last(
    indirect_effects,
    indirect_effects_with_attn_severed,
    indirect_effects_with_mlp_severed,
):
    state_indirect_effects = {
        "Single State": indirect_effects.squeeze().numpy(),
        "SSM Severed": indirect_effects_with_attn_severed.squeeze().numpy(),
        "Gate Severed": indirect_effects_with_mlp_severed.squeeze().numpy(),
    }
    config_color = {
        "Single State": "purple",
        "SSM Severed": "red",
        "Gate Severed": "green",
    }

    # plt.rcdefaults()
    plt.figure(figsize=(20, 6))

    idx = 0
    bar_width = 0.22
    for config in state_indirect_effects:
        plot_ie = []
        for layer in range(mt.n_layer):
            plot_ie.append(state_indirect_effects[config][layer])
        
        plt.bar(
            np.arange(len(plot_ie)) + idx * bar_width, plot_ie,
            width = bar_width,
            label = config,
            # edgecolor = "black",
            color = config_color[config],
            alpha = 0.9
        )
        idx += 1

    def layer_tick(layer_idx, jump=5):
        return f"{layer_idx}" if layer_idx % jump == 0 else ""

    # plt.ylim(0, 1)
    plt.xticks(
        np.arange(mt.n_layer) + bar_width, 
        [layer_tick(i) for i in range(mt.n_layer)]
    )
    
    ylabel = f"Indirect Effect ({'%'} of p(ans) recovered)"

    plt.ylabel(ylabel)
    plt.legend(ncol = 4, bbox_to_anchor=(0.5, -.18), loc='lower center', frameon=False)
    # plt.savefig(f"figs/faithfulness_lre_models.pdf", bbox_inches="tight")
    plt.show()


plot_aie_subject_last(ie, ie_attn_severed, ie_mlp_severed)

# %%
kwargs = dict(
    mt = mt,
    prompt = prompt_template,
    subject = subject,
    alt_subject = alt_subject,
    num_samples = 10,
    noise = 0.1,
    token_range = "prompt_last",
    uniform_noise = False,
    replace = False,
    window = 10,
)

indirect_effect = calculate_hidden_flow_with_ablation(
    **kwargs,
)

indirect_effect_attn_severed = calculate_hidden_flow_with_ablation(
    ablate_transformer_module="attn",
    **kwargs,
)

indirect_effect_mlp_severed = calculate_hidden_flow_with_ablation(
    ablate_transformer_module="mlp",
    **kwargs,
)

high_score = indirect_effect["high_score"].item()
low_score = indirect_effect["low_score"].item()

ie = (indirect_effect["scores"] - low_score) / (high_score - low_score)
ie_attn_severed = (indirect_effect_attn_severed["scores"] - low_score) / (high_score - low_score)
ie_mlp_severed = (indirect_effect_mlp_severed["scores"] - low_score) / (high_score - low_score)

# %%
plot_aie_subject_last(ie, ie_attn_severed, ie_mlp_severed)

# %%
# from src.data.dataclasses import CounterFactDataset

from src.dataset.dataclasses import load_relation
relation = load_relation(file = "../data/relation/factual/place_in_city.json")
relation.select_icl_examples(0)
# Out:
# 2024-04-01 17:30:04 src.dataset.dataclasses INFO     initialized relation -> "place in city" with 154 samples

# %%
question, answer = relation[10]
print(question, end="\n\n")
print(f"{answer=}")
# Out:
# Burj Khalifa is located in the city of
#
# answer='Dubai'

# %%
from src.functional import filter_samples_by_model_knowledge
relation = filter_samples_by_model_knowledge(
    mt = mt,
    relation = relation,
)
# Out:
# 2024-04-01 17:30:04 src.functional DEBUG    "place in city" | filtering with EleutherAI/pythia-2.8b-deduped
# 2024-04-01 17:30:04 src.functional DEBUG    sample.subject='Great Barrier Reef' -> answer='Queensland' | predicted = ' C'(0.254) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Old Havana' -> answer='Havana' | predicted = ' Hav'(0.622) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Kilimanjaro' -> answer='Region' | predicted = ' Mos'(0.919) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Pantheon' -> answer='Rome' | predicted = ' New'(0.028) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Old Town Square' -> answer='Prague' | predicted = ' St'(0.023) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Somerset House' -> answer='London' | predicted = ' London'(0.552) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Yosemite National Park' -> answer='California' | predicted = ' Y'(0.277) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Duomo di Milano' -> answer='Milan' | predicted = ' Milan'(0.734) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='SeaWorld Orlando' -> answer='Orlando' | predicted = ' Orlando'(0.798) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Plitvice Lakes' -> answer='National Park' | predicted = ' K'(0.185) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Burj Khalifa' -> answer='Dubai' | predicted = ' Dubai'(0.952) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Rock of Gibraltar' -> answer='Gibraltar' | predicted = ' Gib'(0.363) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Notre Dame' -> answer='Paris' | predicted = ' South'(0.152) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Rainbow Bridge' -> answer='Tokyo' | predicted = ' San'(0.017) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Milford Sound' -> answer='South Island' | predicted = ' Mil'(0.521) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Grand Canyon' -> answer='Arizona' | predicted = ' Flag'(0.373) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Château de Chambord' -> answer='Chambord' | predicted = ' Ch'(0.544) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Hiroshima Peace Memorial' -> answer='Hiroshima' | predicted = ' Hiro'(0.920) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Kiyomizu-dera' -> answer='Kyoto' | predicted = ' Kyoto'(0.593) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Casa Mila' -> answer='Barcelona' | predicted = ' San'(0.051) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Mont Saint-Michel' -> answer='Normandy' | predicted = ' the'(0.135) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Valley of the Kings' -> answer='Luxor' | predicted = ' Jerusalem'(0.128) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Trevi Fountain' -> answer='Rome' | predicted = ' Rome'(0.840) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Eiffel Tower' -> answer='Paris' | predicted = ' Paris'(0.579) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Banff National Park' -> answer='Alberta' | predicted = ' Ban'(0.848) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Geysir' -> answer='Haukadalur' | predicted = ' G'(0.310) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='The White House' -> answer='Washington D.C.' | predicted = ' Washington'(0.819) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Mount Kilimanjaro' -> answer='Kilimanjaro Region' | predicted = ' Mos'(0.941) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Bran Castle' -> answer='Bran' | predicted = ' Bran'(0.051) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Moraine Lake' -> answer='Alberta' | predicted = ' Mor'(0.039) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Djenne' -> answer='Djenne' | predicted = ' Dj'(0.051) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Uluru' -> answer='Alice Springs' | predicted = ' Alice'(0.506) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Sossusvlei' -> answer='Namib Desert' | predicted = ' Nam'(0.109) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Versailles' -> answer='Versailles' | predicted = ' Vers'(0.218) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Fiordland National Park' -> answer='South Island' | predicted = ' Christ'(0.314) ==> (✗)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Wailing Wall' -> answer='Jerusalem' | predicted = ' Jerusalem'(0.591) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Smithsonian Institution' -> answer='Washington D.C.' | predicted = ' Washington'(0.621) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Canals of Amsterdam' -> answer='Amsterdam' | predicted = ' Amsterdam'(0.958) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject="St. Mark's Basilica" -> answer='Venice' | predicted = ' Venice'(0.911) ==> (✓)
# 2024-04-01 17:30:05 src.functional DEBUG    sample.subject='Hagia Sophia' -> answer='Istanbul' | predicted = ' Istanbul'(0.572) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject="St. Peter's Basilica" -> answer='Vatican City' | predicted = ' Rome'(0.824) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Hermitage Museum' -> answer='Saint Petersburg' | predicted = ' St'(0.384) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Kremlin' -> answer='Moscow' | predicted = ' Moscow'(0.515) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Potala Palace' -> answer='Lhasa' | predicted = ' L'(0.712) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Ha Long Bay' -> answer='Quang Ninh' | predicted = ' N'(0.238) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='La Rambla' -> answer='Barcelona' | predicted = ' Barcelona'(0.593) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Komodo National Park' -> answer='Komodo' | predicted = ' Kom'(0.440) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Harvard University' -> answer='Cambridge' | predicted = ' Cambridge'(0.798) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Auschwitz-Birkenau' -> answer='Oswiecim' | predicted = ' Osw'(0.512) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Karnak' -> answer='Luxor' | predicted = ' Lux'(0.162) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Lincoln Memorial' -> answer='Washington D.C.' | predicted = ' Washington'(0.786) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Lake Bled' -> answer='Bled' | predicted = ' B'(0.729) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Kinkaku-ji' -> answer='Kyoto' | predicted = ' Kyoto'(0.384) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Gullfoss' -> answer='Bláskógabyggð' | predicted = ' Re'(0.304) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Central Park' -> answer='New York' | predicted = ' New'(0.459) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Las Vegas Strip' -> answer='Las Vegas' | predicted = ' Las'(0.796) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Great Ocean Road' -> answer='Victoria' | predicted = ' Melbourne'(0.134) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Krak des Chevaliers' -> answer='Homs' | predicted = ' K'(0.097) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Pyramids' -> answer='Giza' | predicted = ' Al'(0.039) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Art Institute of Chicago' -> answer='Chicago' | predicted = ' Chicago'(0.951) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Santorini' -> answer='Santorini' | predicted = ' N'(0.232) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Cartagena' -> answer='Walled City' | predicted = ' Cart'(0.741) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Park Guell' -> answer='Barcelona' | predicted = ' Barcelona'(0.462) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='CN Tower' -> answer='Toronto' | predicted = ' Toronto'(0.873) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Meenakshi Amman Temple' -> answer='Madurai' | predicted = ' Mad'(0.089) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Capitol Hill' -> answer='Washington D.C.' | predicted = ' Seattle'(0.502) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Anne Frank House' -> answer='Amsterdam' | predicted = ' Amsterdam'(0.671) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Niagara Falls' -> answer='Niagara Falls' | predicted = ' Ni'(0.929) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Buckingham Palace' -> answer='London' | predicted = ' London'(0.798) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Bora Bora' -> answer='Society Islands' | predicted = ' P'(0.215) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Christ the Redeemer' -> answer='Rio de Janeiro' | predicted = ' Rio'(0.819) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Pompeii' -> answer='Pompeii' | predicted = ' Naples'(0.534) ==> (✗)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Royal Palace of Madrid' -> answer='Madrid' | predicted = ' Madrid'(0.939) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='British Museum' -> answer='London' | predicted = ' London'(0.717) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Louvre' -> answer='Paris' | predicted = ' Paris'(0.462) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Table Mountain' -> answer='Cape Town' | predicted = ' Cape'(0.945) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='La Sagrada Familia' -> answer='Barcelona' | predicted = ' Barcelona'(0.961) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Terracotta Army' -> answer="Xi'an" | predicted = ' Xi'(0.564) ==> (✓)
# 2024-04-01 17:30:06 src.functional DEBUG    sample.subject='Golden Gate Bridge' -> answer='San Francisco' | predicted = ' San'(0.731) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Hollywood Sign' -> answer='Los Angeles' | predicted = ' Los'(0.444) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Colosseum' -> answer='Rome' | predicted = ' Rome'(0.754) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Dead Sea' -> answer='Various' | predicted = ' Ein'(0.181) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Yellowstone National Park' -> answer='Wyoming' | predicted = ' Yellow'(0.284) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Red Square' -> answer='Moscow' | predicted = ' Moscow'(0.468) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Mount Everest' -> answer='Solukhumbu' | predicted = ' Kath'(0.107) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Petra' -> answer="Ma'an" | predicted = ' Pet'(0.022) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Parthenon' -> answer='Nashville' | predicted = ' Athens'(0.268) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Matterhorn' -> answer='Zermatt' | predicted = ' Bern'(0.075) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Kremlin and Red Square' -> answer='Moscow' | predicted = ' Moscow'(0.507) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Iguazu Falls' -> answer='Puerto Iguazu' | predicted = ' Rio'(0.179) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Big Sur' -> answer='California' | predicted = ' Carm'(0.300) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Walt Disney World Resort' -> answer='Orlando' | predicted = ' Lake'(0.564) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Museum of Modern Art' -> answer='New York' | predicted = ' New'(0.514) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Sydney Opera House' -> answer='Sydney' | predicted = ' Sydney'(0.948) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Umayyad Mosque' -> answer='Damascus' | predicted = ' Damascus'(0.171) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Machu Picchu' -> answer='Cusco' | predicted = ' C'(0.789) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Space Needle' -> answer='Seattle' | predicted = ' Seattle'(0.976) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Forbidden City' -> answer='Beijing' | predicted = ' Beijing'(0.578) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Summer Palace' -> answer='Beijing' | predicted = ' Beijing'(0.209) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Everglades National Park' -> answer='Florida' | predicted = ' Miami'(0.292) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='La Boca' -> answer='Buenos Aires' | predicted = ' Buenos'(0.269) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Tokyo Tower' -> answer='Tokyo' | predicted = ' Tokyo'(0.521) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject="St. Basil's Cathedral" -> answer='Moscow' | predicted = ' Moscow'(0.297) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Prado Museum' -> answer='Madrid' | predicted = ' Madrid'(0.403) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Willis Tower' -> answer='Chicago' | predicted = ' Chicago'(0.596) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Cape Canaveral' -> answer='Florida' | predicted = ' Cape'(0.308) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Torres del Paine' -> answer='Torres del Paine' | predicted = ' Bar'(0.169) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Teotihuacan' -> answer='San Juan Teotihuacan' | predicted = ' Mexico'(0.325) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Antelope Canyon' -> answer='Arizona' | predicted = ' Flag'(0.228) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Neuschwanstein Castle' -> answer='Hohenschwangau' | predicted = ' Bay'(0.128) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Statue of Liberty' -> answer='New York' | predicted = ' New'(0.775) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Disneyland' -> answer='Anaheim' | predicted = ' Ana'(0.982) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Empire State Building' -> answer='New York' | predicted = ' New'(0.687) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Shwedagon Pagoda' -> answer='Yangon' | predicted = ' B'(0.398) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Great Sphinx' -> answer='Giza' | predicted = ' G'(0.115) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Uffizi Gallery' -> answer='Florence' | predicted = ' Florence'(0.943) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Leaning Tower of Pisa' -> answer='Pisa' | predicted = ' P'(0.908) ==> (✓)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Blue Lagoon' -> answer='Grindavik' | predicted = ' H'(0.030) ==> (✗)
# 2024-04-01 17:30:07 src.functional DEBUG    sample.subject='Nasca Lines' -> answer='Nasca' | predicted = ' N'(0.454) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Sagrada Familia' -> answer='Barcelona' | predicted = ' Barcelona'(0.946) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Sukhothai Historical Park' -> answer='Sukhothai' | predicted = ' S'(0.753) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Carnival of Rio de Janeiro' -> answer='Rio de Janeiro' | predicted = ' Rio'(0.867) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Mount Rushmore' -> answer='South Dakota' | predicted = ' Key'(0.537) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Serengeti National Park' -> answer='Mara Region' | predicted = ' Ar'(0.477) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Plaza de Mayo' -> answer='Buenos Aires' | predicted = ' Buenos'(0.511) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Monte Carlo Casino' -> answer='Monaco' | predicted = ' Monte'(0.092) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Acropolis' -> answer='Athens' | predicted = ' Athens'(0.509) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Mount Kilimanjaro' -> answer='Moshi' | predicted = ' Mos'(0.941) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Mount Fuji' -> answer='Honshu' | predicted = ' Fuj'(0.298) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Brandenburg Gate' -> answer='Berlin' | predicted = ' Berlin'(0.847) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Old Faithful' -> answer='Wyoming' | predicted = ' Yellow'(0.173) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Buckingham Fountain' -> answer='Chicago' | predicted = ' Buck'(0.069) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Borobudur' -> answer='Central Java' | predicted = ' Mag'(0.237) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Louvre Abu Dhabi' -> answer='Abu Dhabi' | predicted = ' Abu'(0.668) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Angkor Wat' -> answer='Siem Reap' | predicted = ' Siem'(0.712) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Prague Castle' -> answer='Prague' | predicted = ' Prague'(0.764) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Pamukkale' -> answer='Denizli Province' | predicted = ' Den'(0.182) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Marrakech Medina' -> answer='Marrakech' | predicted = ' Mar'(0.902) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Sultan Ahmed Mosque' -> answer='Istanbul' | predicted = ' K'(0.049) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Stonehenge' -> answer='Wiltshire' | predicted = ' W'(0.448) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Lake District National Park' -> answer='Cumbria' | predicted = ' K'(0.473) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Times Square' -> answer='New York' | predicted = ' New'(0.770) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Vasa Museum' -> answer='Stockholm' | predicted = ' V'(0.214) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Cliffs of Moher' -> answer='County Clare' | predicted = ' Cl'(0.150) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Sun Temple' -> answer='Konark' | predicted = ' N'(0.042) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Kruger National Park' -> answer='Mpumalanga' | predicted = ' K'(0.225) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Big Ben' -> answer='London' | predicted = ' London'(0.467) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Florence Cathedral' -> answer='Florence' | predicted = ' Florence'(0.826) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Moai' -> answer='Easter Island' | predicted = ' P'(0.085) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Edinburgh Castle' -> answer='Edinburgh' | predicted = ' Edinburgh'(0.970) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Sistine Chapel' -> answer='Vatican City' | predicted = ' Rome'(0.792) ==> (✗)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Arc de Triomphe' -> answer='Paris' | predicted = ' Paris'(0.627) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Gateway Arch' -> answer='St. Louis' | predicted = ' St'(0.888) ==> (✓)
# 2024-04-01 17:30:08 src.functional DEBUG    sample.subject='Vatican Museums' -> answer='Vatican City' | predicted = ' Rome'(0.669) ==> (✗)
# 2024-04-01 17:30:08 src.functional INFO     filtered relation "place in city" to 91 samples (with 0-shots)

# %%
# -------------------------------------------------
n_trials = 50
# -------------------------------------------------

samples = relation.samples[: n_trials]
edit_targets = functional.random_edit_targets(samples = samples)

# %%
from tqdm.auto import tqdm

common_kwargs = dict(
    mt = mt,
    prompt = relation.prompt_templates[0],
    token_range = "subject_last",
    window = 6,
)

all_indirect_effects = []
all_indirect_effects_attn_severed = []
all_indirect_effects_mlp_severed = []

for sample in tqdm(samples):
    alt_sample = edit_targets[sample]

    print(f"sample={str(sample)}, alt_sample={str(alt_sample)}")

    indirect_effect = calculate_hidden_flow_with_ablation(
        subject = sample.subject,
        alt_subject = alt_sample.subject,
        ablate_transformer_module=None,
        **common_kwargs,
    )

    indirect_effect_attn_severed = calculate_hidden_flow_with_ablation(
        subject = sample.subject,
        alt_subject = alt_subject,
        ablate_transformer_module="attn",
        **common_kwargs,
    )

    indirect_effect_mlp_severed = calculate_hidden_flow_with_ablation(
        subject = sample.subject,
        alt_subject = alt_subject,
        ablate_transformer_module="mlp",
        **common_kwargs,
    )

    high_score = indirect_effect["high_score"].item()
    low_score = indirect_effect["low_score"].item()

    ie = (indirect_effect["scores"] - low_score) / (high_score - low_score)
    ie_attn_severed = (indirect_effect_attn_severed["scores"] - low_score) / (high_score - low_score)
    ie_mlp_severed = (indirect_effect_mlp_severed["scores"] - low_score) / (high_score - low_score)

    all_indirect_effects.append(ie)
    all_indirect_effects_attn_severed.append(ie_attn_severed)
    all_indirect_effects_mlp_severed.append(ie_mlp_severed)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# sample=Old Havana -> Havana, alt_sample=Komodo National Park -> Komodo
# sample=Somerset House -> London, alt_sample=Lincoln Memorial -> Washington D.C.
# sample=Duomo di Milano -> Milan, alt_sample=Versailles -> Versailles
# sample=SeaWorld Orlando -> Orlando, alt_sample=Hiroshima Peace Memorial -> Hiroshima
# sample=Burj Khalifa -> Dubai, alt_sample=Central Park -> New York
# sample=Rock of Gibraltar -> Gibraltar, alt_sample=Kinkaku-ji -> Kyoto
# sample=Château de Chambord -> Chambord, alt_sample=Las Vegas Strip -> Las Vegas
# sample=Hiroshima Peace Memorial -> Hiroshima, alt_sample=Christ the Redeemer -> Rio de Janeiro
# sample=Kiyomizu-dera -> Kyoto, alt_sample=Central Park -> New York
# sample=Trevi Fountain -> Rome, alt_sample=Royal Palace of Madrid -> Madrid
# sample=Eiffel Tower -> Paris, alt_sample=Meenakshi Amman Temple -> Madurai
# sample=The White House -> Washington D.C., alt_sample=Eiffel Tower -> Paris
# sample=Bran Castle -> Bran, alt_sample=Park Guell -> Barcelona
# sample=Djenne -> Djenne, alt_sample=Château de Chambord -> Chambord
# sample=Uluru -> Alice Springs, alt_sample=Buckingham Palace -> London
# sample=Sossusvlei -> Namib Desert, alt_sample=Buckingham Palace -> London
# sample=Versailles -> Versailles, alt_sample=Niagara Falls -> Niagara Falls
# sample=Wailing Wall -> Jerusalem, alt_sample=Terracotta Army -> Xi'an
# sample=Smithsonian Institution -> Washington D.C., alt_sample=CN Tower -> Toronto
# sample=Canals of Amsterdam -> Amsterdam, alt_sample=Burj Khalifa -> Dubai
# sample=St. Mark's Basilica -> Venice, alt_sample=Kinkaku-ji -> Kyoto
# sample=Hagia Sophia -> Istanbul, alt_sample=Central Park -> New York
# sample=Kremlin -> Moscow, alt_sample=Anne Frank House -> Amsterdam
# sample=Potala Palace -> Lhasa, alt_sample=Wailing Wall -> Jerusalem
# sample=La Rambla -> Barcelona, alt_sample=Djenne -> Djenne
# sample=Komodo National Park -> Komodo, alt_sample=Trevi Fountain -> Rome
# sample=Harvard University -> Cambridge, alt_sample=Kiyomizu-dera -> Kyoto
# sample=Auschwitz-Birkenau -> Oswiecim, alt_sample=Anne Frank House -> Amsterdam
# sample=Karnak -> Luxor, alt_sample=Canals of Amsterdam -> Amsterdam
# sample=Lincoln Memorial -> Washington D.C., alt_sample=Park Guell -> Barcelona
# sample=Lake Bled -> Bled, alt_sample=Terracotta Army -> Xi'an
# sample=Kinkaku-ji -> Kyoto, alt_sample=Las Vegas Strip -> Las Vegas
# sample=Central Park -> New York, alt_sample=Art Institute of Chicago -> Chicago
# sample=Las Vegas Strip -> Las Vegas, alt_sample=Art Institute of Chicago -> Chicago
# sample=Art Institute of Chicago -> Chicago, alt_sample=Kremlin -> Moscow
# sample=Park Guell -> Barcelona, alt_sample=Somerset House -> London
# sample=CN Tower -> Toronto, alt_sample=Kiyomizu-dera -> Kyoto
# sample=Meenakshi Amman Temple -> Madurai, alt_sample=Kremlin -> Moscow
# sample=Anne Frank House -> Amsterdam, alt_sample=Bran Castle -> Bran
# sample=Niagara Falls -> Niagara Falls, alt_sample=Wailing Wall -> Jerusalem
# sample=Buckingham Palace -> London, alt_sample=Anne Frank House -> Amsterdam
# sample=Christ the Redeemer -> Rio de Janeiro, alt_sample=Central Park -> New York
# sample=Royal Palace of Madrid -> Madrid, alt_sample=St. Mark's Basilica -> Venice
# sample=British Museum -> London, alt_sample=Potala Palace -> Lhasa
# sample=Louvre -> Paris, alt_sample=Wailing Wall -> Jerusalem
# sample=Table Mountain -> Cape Town, alt_sample=Rock of Gibraltar -> Gibraltar
# sample=La Sagrada Familia -> Barcelona, alt_sample=Canals of Amsterdam -> Amsterdam
# sample=Terracotta Army -> Xi'an, alt_sample=Burj Khalifa -> Dubai
# sample=Golden Gate Bridge -> San Francisco, alt_sample=Rock of Gibraltar -> Gibraltar
# sample=Hollywood Sign -> Los Angeles, alt_sample=Louvre -> Paris

# %%
avg_indirect_effects = torch.stack(all_indirect_effects).squeeze().mean(dim=0)
avg_indirect_effects_attn_severed = torch.stack(all_indirect_effects_attn_severed).squeeze().mean(dim=0)
avg_indirect_effects_mlp_severed = torch.stack(all_indirect_effects_mlp_severed).squeeze().mean(dim=0)

plot_aie_subject_last(
    avg_indirect_effects, 
    avg_indirect_effects_attn_severed, 
    avg_indirect_effects_mlp_severed
)

# %%
from tqdm.auto import tqdm

common_kwargs = dict(
    mt = mt,
    prompt = relation.prompt_templates[0],
    token_range = "prompt_last",
    window = 6,
)

all_indirect_effects = []
all_indirect_effects_attn_severed = []
all_indirect_effects_mlp_severed = []

for sample in tqdm(samples):
    alt_sample = edit_targets[sample]

    print(f"sample={str(sample)}, alt_sample={str(alt_sample)}")

    indirect_effect = calculate_hidden_flow_with_ablation(
        subject = sample.subject,
        alt_subject = alt_sample.subject,
        ablate_transformer_module=None,
        **common_kwargs,
    )

    indirect_effect_attn_severed = calculate_hidden_flow_with_ablation(
        subject = sample.subject,
        alt_subject = alt_subject,
        ablate_transformer_module="attn",
        **common_kwargs,
    )

    indirect_effect_mlp_severed = calculate_hidden_flow_with_ablation(
        subject = sample.subject,
        alt_subject = alt_subject,
        ablate_transformer_module="mlp",
        **common_kwargs,
    )

    high_score = indirect_effect["high_score"].item()
    low_score = indirect_effect["low_score"].item()

    ie = (indirect_effect["scores"] - low_score) / (high_score - low_score)
    ie_attn_severed = (indirect_effect_attn_severed["scores"] - low_score) / (high_score - low_score)
    ie_mlp_severed = (indirect_effect_mlp_severed["scores"] - low_score) / (high_score - low_score)

    all_indirect_effects.append(ie)
    all_indirect_effects_attn_severed.append(ie_attn_severed)
    all_indirect_effects_mlp_severed.append(ie_mlp_severed)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# sample=Old Havana -> Havana, alt_sample=Komodo National Park -> Komodo
# sample=Somerset House -> London, alt_sample=Lincoln Memorial -> Washington D.C.
# sample=Duomo di Milano -> Milan, alt_sample=Versailles -> Versailles
# sample=SeaWorld Orlando -> Orlando, alt_sample=Hiroshima Peace Memorial -> Hiroshima
# sample=Burj Khalifa -> Dubai, alt_sample=Central Park -> New York
# sample=Rock of Gibraltar -> Gibraltar, alt_sample=Kinkaku-ji -> Kyoto
# sample=Château de Chambord -> Chambord, alt_sample=Las Vegas Strip -> Las Vegas
# sample=Hiroshima Peace Memorial -> Hiroshima, alt_sample=Christ the Redeemer -> Rio de Janeiro
# sample=Kiyomizu-dera -> Kyoto, alt_sample=Central Park -> New York
# sample=Trevi Fountain -> Rome, alt_sample=Royal Palace of Madrid -> Madrid
# sample=Eiffel Tower -> Paris, alt_sample=Meenakshi Amman Temple -> Madurai
# sample=The White House -> Washington D.C., alt_sample=Eiffel Tower -> Paris
# sample=Bran Castle -> Bran, alt_sample=Park Guell -> Barcelona
# sample=Djenne -> Djenne, alt_sample=Château de Chambord -> Chambord
# sample=Uluru -> Alice Springs, alt_sample=Buckingham Palace -> London
# sample=Sossusvlei -> Namib Desert, alt_sample=Buckingham Palace -> London
# sample=Versailles -> Versailles, alt_sample=Niagara Falls -> Niagara Falls
# sample=Wailing Wall -> Jerusalem, alt_sample=Terracotta Army -> Xi'an
# sample=Smithsonian Institution -> Washington D.C., alt_sample=CN Tower -> Toronto
# sample=Canals of Amsterdam -> Amsterdam, alt_sample=Burj Khalifa -> Dubai
# sample=St. Mark's Basilica -> Venice, alt_sample=Kinkaku-ji -> Kyoto
# sample=Hagia Sophia -> Istanbul, alt_sample=Central Park -> New York
# sample=Kremlin -> Moscow, alt_sample=Anne Frank House -> Amsterdam
# sample=Potala Palace -> Lhasa, alt_sample=Wailing Wall -> Jerusalem
# sample=La Rambla -> Barcelona, alt_sample=Djenne -> Djenne
# sample=Komodo National Park -> Komodo, alt_sample=Trevi Fountain -> Rome
# sample=Harvard University -> Cambridge, alt_sample=Kiyomizu-dera -> Kyoto
# sample=Auschwitz-Birkenau -> Oswiecim, alt_sample=Anne Frank House -> Amsterdam
# sample=Karnak -> Luxor, alt_sample=Canals of Amsterdam -> Amsterdam
# sample=Lincoln Memorial -> Washington D.C., alt_sample=Park Guell -> Barcelona
# sample=Lake Bled -> Bled, alt_sample=Terracotta Army -> Xi'an
# sample=Kinkaku-ji -> Kyoto, alt_sample=Las Vegas Strip -> Las Vegas
# sample=Central Park -> New York, alt_sample=Art Institute of Chicago -> Chicago
# sample=Las Vegas Strip -> Las Vegas, alt_sample=Art Institute of Chicago -> Chicago
# sample=Art Institute of Chicago -> Chicago, alt_sample=Kremlin -> Moscow
# sample=Park Guell -> Barcelona, alt_sample=Somerset House -> London
# sample=CN Tower -> Toronto, alt_sample=Kiyomizu-dera -> Kyoto
# sample=Meenakshi Amman Temple -> Madurai, alt_sample=Kremlin -> Moscow
# sample=Anne Frank House -> Amsterdam, alt_sample=Bran Castle -> Bran
# sample=Niagara Falls -> Niagara Falls, alt_sample=Wailing Wall -> Jerusalem
# sample=Buckingham Palace -> London, alt_sample=Anne Frank House -> Amsterdam
# sample=Christ the Redeemer -> Rio de Janeiro, alt_sample=Central Park -> New York
# sample=Royal Palace of Madrid -> Madrid, alt_sample=St. Mark's Basilica -> Venice
# sample=British Museum -> London, alt_sample=Potala Palace -> Lhasa
# sample=Louvre -> Paris, alt_sample=Wailing Wall -> Jerusalem
# sample=Table Mountain -> Cape Town, alt_sample=Rock of Gibraltar -> Gibraltar
# sample=La Sagrada Familia -> Barcelona, alt_sample=Canals of Amsterdam -> Amsterdam
# sample=Terracotta Army -> Xi'an, alt_sample=Burj Khalifa -> Dubai
# sample=Golden Gate Bridge -> San Francisco, alt_sample=Rock of Gibraltar -> Gibraltar
# sample=Hollywood Sign -> Los Angeles, alt_sample=Louvre -> Paris

# %%
avg_indirect_effects = torch.stack(all_indirect_effects).squeeze().mean(dim=0)
avg_indirect_effects_attn_severed = torch.stack(all_indirect_effects_attn_severed).squeeze().mean(dim=0)
avg_indirect_effects_mlp_severed = torch.stack(all_indirect_effects_mlp_severed).squeeze().mean(dim=0)

plot_aie_subject_last(
    avg_indirect_effects, 
    avg_indirect_effects_attn_severed, 
    avg_indirect_effects_mlp_severed
)
